# %% [markdown]
# <a href="https://colab.research.google.com/github/sourajroy-afk/BA-using-PYTHON-/blob/main/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **FUNCTIONS**

# %%
'''
len(), type(), sum(), max(), min(), and input()''' #these are built-in functions in python.

# %%
'''Write a function that returns factorial of a number.

Write a function that returns the greater of two numbers.
'''



a=int(input("enter the number"))
def factorial(a):
 for i in range(1,a):
    a=a*i
 print(a)
factorial(a)

# %%
a,b=(int(input("enter the 1st number")), int(input("enter the 2nd number")))

def comparison():
 if (a>b and a!=b):
  print(a)

 else:
  print(b)
comparison()
# Out:
# enter the 1st number45
# enter the 2nd number45
# 45

# %%
#Write a function that returns sum, average, and product of a list.

a,b,c = (int(input("enter the 1st number")), int(input("enter the 2nd number")), int(input("enter the 3rd number")))

def function(a,b,c):
 sum=a+b+c
 average=sum/3
 product=a*b*c
 return sum, average, product

function(a,b,c)
# Out:
# enter the 1st number3
# enter the 2nd number4
# enter the 3rd number5
# (12, 4.0, 60)

# %%
#Write a function that takes price & discount and returns final amount

price=int(input("enter the price"))
discount=int(input("enter the discount"))

def function(price,discount):
  final_amount=price-(price*discount)/100
  return final_amount
function(price,discount)
# Out:
# enter the price300
# enter the discount10
# 270.0

# %%
#Write a function that returns the number of uppercase and lowercase letters in a string.

write=input("enter the string")
def function():
 upper_case=write.upper()
 lower_case=write.lower()
 return upper_case, lower_case
function()
# Out:
# enter the stringsoURaj
# ('SOURAJ', 'souraj')

# %%
#Write a function that returns the 2nd largest number in a list.


# Take number of elements
n = int(input("Enter the number of elements: "))

# Create empty list
list1 = []

# Take input inside list
for i in range(n):
    value = int(input("Enter value: "))
    list1.append(value)

def souraj(number):
      number.sort()
      return number

      print(souraj(list1))
# Out:
# Enter the number of elements: 2
# Enter value: 22
# Enter value: 111
