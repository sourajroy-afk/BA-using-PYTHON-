# %% [markdown]
# <a href="https://colab.research.google.com/github/sourajroy-afk/BA-using-PYTHON-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("siom")
''' naming convention in python  for variable
you can't start variable with numbers '''
# Out:
# siom
# " naming convention in python  for variable \nyou can't start variable with numbers "

# %%
x= "siom"
X="SIOM"
y="Supratim"
print(x,X,y,sep="\n")
# Out:
# siom
# SIOM
# Supratim

# %%
Path ="C:\newfolder\test"
print(Path)
# Out:
# C:
# ewfolder	est

# %%
Path=r"C:\newfolder\test"
print(Path)
#The r prefix before the string indicates it's a raw string, meaning backslashes are treated as literal characters, which is common for file paths.
# Out:
# C:\newfolder\test
# "The r prefix before the string indicates it's a raw string, meaning backslashes are treated as literal characters, which is common for file paths."

# %%
Name="Souraj"
Age= 25
print("My name is " + Name + " and age is",Age)
print(f"My name is {Name} \nMy age is {Age}")
# Out:
# My name is Souraj and age is 25
# My name is Souraj
# My age is 25

# %%
#data type
a=10
b=5.5
c="ROY"
d=False
print(type(a),type(b),type(c),type(d))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
a="A"
print(ord(a))
# Out:
# 65

# %%
import sys
sys.getsizeof("souraj ddhdhhdh")
# Out:
# 56

# %%
sys.getsizeof(123456789999999999090888)
# Out:
# 36

# %%
#type casting(explicit)
z=5
t=float(z)
print(t)
# Out:
# 5.0

# %%
#type casting (implicit)

a=2
b=5
c=b/a
print(c)
print(type(c))
# Out:
# 2.5
# <class 'float'>

# %%
sname=input("enter your name ")
if sname.isalpha():
    sage=input("enter your age ")
    if sage.isnumeric():
        sage=int(sage)
    print(f"student name is {sname} and age is {sage}")
else:
    print("invalid")
# Out:
# enter your name 55
# invalid

# %%
#operator
#Arithmatic Operator
x=10
y=6
a=x*y
print(a);
#relational operator / comparison operator
print(10>5)

#logical operator
age= input("enter your age")
age=int(age)
print(age > 18 and age < 40)

#membership operator
fruits=["apple","banana","cherry"]
print("apple" in fruits)

#identity operator
a=10
b=10
print(a is b)

#bitwise operator[basically the binary operation]
print(10 & 12)
# Out:
# 60
# True
# enter your age60
# False
# True
# True
# 8

# %%
 ''' Level 1

Write Python expressions to calculate:

1. Area of a circle

2. Simple interest

3. Check whether 25 is greater than 15.

4. Write a program that checks if a number is between 10 and 20.

5. Convert "45.67" (string) to float and add 10.

6. Given list = [10, 20, 30, 40], check if 25 is in the list.

7. Compare identity of two lists.
'''

r = int(input("enter the radius of circle"))
area = 22.7*r*r
print("The area of the circle" ,area)
# Out:
# enter the radius of circle5
# The area of the circle 567.5

# %%
p=int(input("enter the principle"))
r=int(input("enter the rate"))
t=int(input("enter the time"))
si=(p*r*t)/100
print("interest",si)
# Out:
# enter the principle500
# enter the rate5
# enter the time4
# interest 100.0

# %%
print(25>15)
# Out:
# True

# %%
a= int(input( "please enter a number"))
print (a>10 and a<20)
# Out:
# please enter a number30
# False

# %%
a="45.67"
b=float(a)
print(b+10)
# Out:
# 55.67

# %%
number=[10, 20, 30, 40]
print(25 in number)
# Out:
# False

# %%
a=[1,2,3]
b=[1,2,3]

print(a ==b)
print(a is b)

''' == checks values (content inside list).

is checks identity (whether both variables refer to the same memory location).'''
# Out:
# True
# False

# %%
''' Case:

A company wants to check if a customer's purchase amount qualifies for extra discount (> ₹5000) AND if the customer is a loyalty member. '''

purchase_amount=int(input("enter the purchase amount"))
loyality_member=input("are you a loyality member")
if purchase_amount > 5000 and loyality_member == "yes":
   print("you are eligible for extra discount")
else:
    print("you are not eligible for extra discount")
# Out:
# enter the purchase amount7000
# are you a loyality memberyes
# you are eligible for extra discount
